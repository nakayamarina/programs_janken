# %% [markdown]
# # 識別率の高いボクセルのブロードマンエリア特定

# %% [markdown]
# ----
#
# 引数：識別率一覧/ボクセル-ブロードマンエリア対応表が記録されたcsvファイルがあるディレクトリまでのパス
#
# ---
#
# 入力：識別率一覧 ACCURACY[loo]_Voxtimseries30_SVM.csv / ボクセル-ブロードマンエリア対応表 Voxel_Brodmann_Table.csv
#
# ---
#
# 出力：Accuracy_Brodmann_Table.csv
#
# ---
#
# 各ボクセルがどのブロードマンエリアであるかを特定，識別率が高い順に並べ替える．

# %%
from os.path import join as pathjoin
from pprint import pprint
# from nifti import NiftiImage
import glob
import numpy as np
import pandas as pd
import sys
import pickle
# import dill
import csv

# %%
# args = sys.argv
# PATH = args[1]

#jupyter notebookのときはここで指定
PATH = '../Sta'

# 識別率一覧を記録したcsvファイルへのパス
PATH_ac = PATH + 'ACMID1[loo]_VOXtimeseries30_SVM.csv'

# ボクセル-ブロードマンエリア対応表を記録したファイルへのパス
PATH_tab = PATH + 'VoxelBrodmannTable.csv'

# %%
# 識別率一覧を読み込み
ac = pd.read_csv(PATH_ac, header = 0)
ac.columns = brainAc.columns = ['BAvoxelNum', 'accuracy(%)']

# %%
# ボクセル-ブロードマンエリア対応表を読み込み
tab = pd.read_csv(PATH_tab, header = 0)

# %%
# acとtabをマージすることで各ボクセルのブロードマンエリアを特定
AcTab = pd.merge(ac, tab, on = ['BAvoxelNum'], how = 'left')

# %%
# BAvoxelNumとaccuracyを行名に設定することで(MultiIndex)重複を分かりやすくする
# (一つのボクセルに対して複数のブロードマンエリアが対応していることがある）
AcTab = AcTab.set_index(['BAvoxelNum', 'accuracy(%)'])

# %%
# accuracyでソートすることで識別率の高い順に並べる
# (MultiIndexの時は)levelでどのインデックスでソートするか指定，ascending = Falseとすることで昇順に
AcTab = AcTab.sort_index(level = 'accuracy(%)', ascending = False)

# %%
AcTab
# Out:
#                         x   y   z    BrodmannArea
# BAvoxelNum accuracy(%)
# Voxel1078  71.2         7  50  37  BrodmannArea22
# Voxel1668  71.0         8  51  36  BrodmannArea22
# Voxel1055  70.6         7  49  37  BrodmannArea22
# Voxel1103  69.9         7  51  37  BrodmannArea22
# Voxel1575  69.5         8  45  41  BrodmannArea42
# Voxel1054  69.5         7  49  36  BrodmannArea22
# Voxel1031  69.5         7  47  41  BrodmannArea42
# Voxel1220  69.3         8  21  46  BrodmannArea39
# Voxel1042  69.3         7  48  37  BrodmannArea22
# Voxel1652  67.8         8  50  37  BrodmannArea22
# Voxel1591  67.6         8  46  41  BrodmannArea42
# Voxel1574  67.6         8  45  40  BrodmannArea42
# Voxel1255  67.6         8  24  45  BrodmannArea39
# Voxel1239  67.6         8  24  26  BrodmannArea37
# Voxel1590  67.4         8  46  40  BrodmannArea42
# Voxel1043  66.9         7  48  42  BrodmannArea43
# Voxel1001  66.9         7  45  42  BrodmannArea40
# Voxel1943  66.7         9  25  26  BrodmannArea37
# Voxel1689  66.7         8  52  36  BrodmannArea22
# Voxel1589  66.7         8  46  35  BrodmannArea22
# Voxel1576  66.5         8  45  42  BrodmannArea40
# Voxel1273  66.5         8  25  45  BrodmannArea39
# Voxel1237  66.1         8  23  46  BrodmannArea39
# Voxel1030  66.1         7  47  40  BrodmannArea42
# Voxel1128  65.7         7  52  37  BrodmannArea22
# Voxel1688  65.5         8  52  35  BrodmannArea22
# Voxel1577  65.5         8  45  43  BrodmannArea40
# Voxel1558  65.5         8  44  40  BrodmannArea42
# Voxel1041  65.5         7  48  36  BrodmannArea22
# Voxel1608  65.0         8  47  41  BrodmannArea42
# ...                    ..  ..  ..             ...
# Voxel1831  1.3          8  60  47   BrodmannArea9
# Voxel1805  1.3          8  57  48   BrodmannArea6
# Voxel1356  1.3          8  30  51  BrodmannArea40
# Voxel1169  1.3          7  54  47   BrodmannArea6
# Voxel1045  1.3          7  48  50         unknown
# Voxel1185  1.1          7  55  48   BrodmannArea6
# Voxel1089  1.1          7  50  53   BrodmannArea6
# Voxel1828  0.8          8  59  47   BrodmannArea9
# Voxel1639  0.8          8  49  50   BrodmannArea3
# Voxel1355  0.8          8  30  50  BrodmannArea40
# Voxel1259  0.8          8  25  30  BrodmannArea37
# Voxel1244  0.8          8  24  31  BrodmannArea37
# Voxel1066  0.8          7  49  54   BrodmannArea6
# Voxel1260  0.6          8  25  31  BrodmannArea37
# Voxel1087  0.6          7  50  51   BrodmannArea6
# Voxel1892  0.4          9  22  31  BrodmannArea19
# Voxel1829  0.4          8  59  48   BrodmannArea9
# Voxel1243  0.4          8  24  30  BrodmannArea37
# Voxel1088  0.4          7  50  52   BrodmannArea6
# Voxel1923  0.2          9  24  30  BrodmannArea37
# Voxel1830  0.2          8  59  49   BrodmannArea9
# Voxel1786  0.2          8  57  25  BrodmannArea21
# Voxel1170  0.2          7  54  48   BrodmannArea6
# Voxel1065  0.2          7  49  53   BrodmannArea6
# Voxel1062  0.2          7  49  50   BrodmannArea3
# Voxel1906  0.0          9  23  31  BrodmannArea37
# Voxel1640  0.0          8  49  51   BrodmannArea4
# Voxel1516  0.0          8  41  49  BrodmannArea40
# Voxel1064  0.0          7  49  52         unknown
# Voxel1063  0.0          7  49  51   BrodmannArea4
#
# [1003 rows x 4 columns]
